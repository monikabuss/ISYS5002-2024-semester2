# %% [markdown]
# <a href="https://colab.research.google.com/github/monikabuss/ISYS5002-2024-semester2/blob/main/05_2_using_paycalc(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## import paycalc module

# %%
import paycalc as pay
help(pay)
# Out:
# Help on module paycalc:
#
# NAME
#     paycalc - 05_2_paycalc(1).ipynb
#
# DESCRIPTION
#     Automatically generated by Colab.
#
#     Original file is located at
#         https://colab.research.google.com/drive/1eXkQnyfwdFB563cWxBdp-m4ASjBGrBLS
#
# FUNCTIONS
#     calculate_pay(salary, sales, comm)
#         This function calculates the commission, tax, and pay for a given salary, sales, and commission rate.
#
#         Inputs:
#         salary: an integer representing the user's salary
#         sales: an integer representing the user's sales
#         comm: a float representing the user's commission rate
#
#         Returns:
#         commission: a float representing the commission earned based on the sales and commission rate
#         tax: a float representing the tax amount calculated based on the salary and commission earned
#         pay: a float representing the pay after deducting tax from the salary and adding the commission earned
#
#     calculate_tax(income)
#
# ...

# %% [markdown]
# ## call the relevant functions from the `paycalc` module to
# * get user input
# * calculate the pay
# * print the payslip

# %%
5
name, sal, sales, comm = pay.user_input()
# Out:
# Please enter name: monika
# Please enter salary: 50000
# Please enter sales: 400
# Please enter commission rate: 2

# %%
commission, tax, payment = pay.calculate_pay(sal, sales, comm)

# %%
pay.print_payslip(name, sal, commission, tax, payment)
# Out:
# === Payslip of monika ===
# Salary:     50000
# Commission: 8.0
# Tax: 6694.5599999999995
# Total pay: 43313.44
